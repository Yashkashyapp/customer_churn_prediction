# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
file = pd.read_csv('c:/Users/kashy/Downloads/Capstone-project-2/Dataset/Dataset/customer_churn.csv')
print(file.shape)
# Out:
# (7043, 21)

# %%
file.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
customer_5 = file.loc[0:,['Dependents']]
customer = file.iloc[:,4]

# %%
customer_5.head()
# Out:
#   Dependents
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No

# %%
customer_15 = file.iloc[:,14]
customer_15.head
# Out:
# <bound method NDFrame.head of 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 7038    Yes
# 7039    Yes
# 7040     No
# 7041     No
# 7042    Yes
# Name: StreamingMovies, Length: 7043, dtype: object>

# %%
senior_male_electronic = (file['gender']=='Male') & (file['PaymentMethod']=='Electronic check')
fl = file[(file['gender']=='Male') & (file['PaymentMethod']=='Electronic check')]

# %%
fl.head()
# Out:
#     customerID gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 14  5129-JLPIS   Male              0      No         No      25          Yes
# 20  8779-QRDMV   Male              1      No         No       1           No
# 26  6467-CHFZW   Male              0     Yes        Yes      47          Yes
# 27  8665-UTDHZ   Male              0     Yes        Yes       1           No
# 36  6047-YHPVI   Male              0      No         No       5          Yes
#
#        MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 14                No     Fiber optic            Yes  ...              Yes
# 20  No phone service             DSL             No  ...              Yes
# 26               Yes     Fiber optic             No  ...               No
# 27  No phone service             DSL             No  ...               No
# 36                No     Fiber optic             No  ...               No
#
# ...

# %%
customer_total_tenure = (file['tenure']<70) & (file['MonthlyCharges']<100)
cs = file[(file['tenure']<70) & (file['MonthlyCharges']<100)]

# %%
cs.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
two_mail_yes = (file['Contract']=='Two year') & (file['PaymentMethod']=='Mailed check') & (file['Churn']=='Yes')
mail = file[(file['Contract']=='Two year') & (file['PaymentMethod']=='Mailed check') & (file['Churn']=='Yes')]

# %%
mail.head()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 268   6323-AYBRX    Male              0      No         No      59
# 5947  7951-QKZPL  Female              0     Yes        Yes      33
# 6680  9412-ARGBX  Female              0      No        Yes      48
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 268           Yes            No              No  No internet service  ...
# 5947          Yes           Yes              No  No internet service  ...
# 6680          Yes            No     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 268   No internet service  No internet service  No internet service
# 5947  No internet service  No internet service  No internet service
# 6680                  Yes                  Yes                  Yes
#
#           StreamingMovies  Contract PaperlessBilling PaymentMethod  \
# ...

# %%
customer_333 = file.sample(333)
customer_333.head()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3832  4626-OZDTJ  Female              0     Yes         No      51
# 5632  5567-GZKQY    Male              0      No         No      58
# 1942  3764-MNMOI    Male              0      No         No      46
# 2180  7375-WMVMT    Male              1     Yes         No      71
# 5437  7000-WCEVQ  Female              1      No         No      20
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 3832          Yes           Yes             DSL                   No  ...
# 5632          Yes            No              No  No internet service  ...
# 1942          Yes            No              No  No internet service  ...
# 2180          Yes            No     Fiber optic                   No  ...
# 5437          Yes           Yes             DSL                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
file['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
file['PaymentMethod'].value_counts().keys()
# Out:
# Index(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'],
#       dtype='object', name='PaymentMethod')

# %%
x = (file['InternetService'].value_counts().keys())
y = (file['InternetService'].value_counts())

# %%
plt.bar(x,y,color='orange')
plt.xlabel("Internet Services")
plt.ylabel("count of categorie")
plt.title('distibution of internet service')
plt.show()

# %%
plt.hist(file['tenure'],bins=30,color='green',edgecolor='black')
plt.title('distribution of tenure')
plt.show()

# %%
x = (file['tenure'])
y = (file['MonthlyCharges'])
plt.scatter(x,y,color='brown')
plt.xlabel('tenure of customer')
plt.ylabel('monthly charges of customer')
plt.show()

# %%
file.boxplot(column=['tenure'],by=['Contract'])
# Out:
# <Axes: title={'center': 'tenure'}, xlabel='[Contract]'>

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.model_selection import train_test_split
x = file[['tenure']]
y = file[['MonthlyCharges']]

x_train,x_test,y_train, y_test= train_test_split(x,y,test_size=0.3)

regressor = LinearRegression()
regressor.fit(x_train,y_train)

y_predict = regressor.predict(x_test)

print('intercept:', regressor.intercept_)
print('coef',regressor.coef_)
from sklearn.metrics import mean_squared_error
print('RMSE:', np.sqrt(mean_squared_error(y_test,y_predict)))
# Out:
# intercept: [55.49787957]
# coef [[0.30218363]]
# RMSE: 29.73421442360368

# %%
from sklearn.linear_model import LogisticRegression 
from sklearn.model_selection import train_test_split
x = file[['MonthlyCharges']]
y = file[['Churn']]

x_train,x_test,y_train, y_test= train_test_split(x,y,test_size=0.35)

regressor = LogisticRegression()
regressor.fit(x_train,y_train)

y_predict = regressor.predict(x_test)

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
print('accuracy_score:',accuracy_score(y_test,y_predict))
print('confusionmatrix:',confusion_matrix(y_test,y_predict))
# Out:
# accuracy_score: 0.7441200324412003
# confusionmatrix: [[1835    0]
#  [ 631    0]]
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn.linear_model import LogisticRegression 
from sklearn.model_selection import train_test_split
x = file[['MonthlyCharges','tenure']] 
y = file[['Churn']]

x_train,x_test,y_train, y_test= train_test_split(x,y,test_size=0.20)

regressor = LogisticRegression()
regressor.fit(x_train,y_train)

y_predict = regressor.predict(x_test)

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
print('accuracy_score:',accuracy_score(y_test,y_predict))
print('confusionmatrix:',confusion_matrix(y_test,y_predict))
# Out:
# accuracy_score: 0.7920511000709723
# confusionmatrix: [[956 100]
#  [193 160]]
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
x = file[['tenure']] 
y = file[['Churn']]

x_train,x_test,y_train, y_test= train_test_split(x,y,test_size=0.20)

regressor = DecisionTreeClassifier()
regressor.fit(x_train,y_train)

y_predict = regressor.predict(x_test)

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
print('accuracy_score:',accuracy_score(y_test,y_predict))
print('confusionmatrix:',confusion_matrix(y_test,y_predict))
# Out:
# accuracy_score: 0.7423704755145494
# confusionmatrix: [[945  69]
#  [294 101]]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
x = file[['MonthlyCharges','tenure']] 
y = file[['Churn']]

x_train,x_test,y_train, y_test= train_test_split(x,y,test_size=0.30)

regressor = RandomForestClassifier()
regressor.fit(x_train,y_train)

y_predict = regressor.predict(x_test)

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
print('accuracy_score:',accuracy_score(y_test,y_predict))
print('confusionmatrix:',confusion_matrix(y_test,y_predict))
# Out:
# D:\anaconda\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# accuracy_score: 0.7553241836251775
# confusionmatrix: [[1332  194]
#  [ 323  264]]
